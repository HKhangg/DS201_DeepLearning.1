# %%
# !git clone https://github.com/HKhangg/DS201_DeepLearning.1.git
# Out:
# Cloning into 'DS201_DeepLearning.1'...
# remote: Enumerating objects: 148, done.
# remote: Counting objects: 100% (148/148), done.
# remote: Compressing objects: 100% (95/95), done.
# remote: Total 148 (delta 47), reused 146 (delta 45), pack-reused 0 (from 0)
# Receiving objects: 100% (148/148), 13.47 MiB | 22.29 MiB/s, done.
# Resolving deltas: 100% (47/47), done.

# %%
# %cd DS201_DeepLearning.1/Lab4
# Out:
# /kaggle/working/DS201_DeepLearning.1/Lab4/DS201_DeepLearning.1/Lab4/DS201_DeepLearning.1/Lab4/DS201_DeepLearning.1/Lab4/DS201_DeepLearning.1/Lab4/DS201_DeepLearning.1/Lab4

# %%
# !pip install rouge -q

# %% [markdown]
# ## BÀI 1: Basic Seq2Seq (No Attention)
#
# **Yêu cầu:**
# - Encoder-Decoder với 3 layers LSTM
# - Hidden size: 256
# - Optimizer: Adam
# - Metric: ROUGE-L

# %%
# %%time
# Chạy Assignment 1: Basic Seq2Seq
# !python main.py \
    --assignment 1 \
    --train_path /kaggle/input/phomt-data/small-train.json \
    --val_path /kaggle/input/phomt-data/small-dev.json \
    --test_path /kaggle/input/phomt-data/small-test.json \
    --embedding_dim 256 \
    --hidden_dim 256 \
    --num_layers 3 \
    --dropout 0.3 \
    --batch_size 32 \
    --epochs 5 \
    --patience 5 \
    --lr 0.001 \
    --log_dir logs/assignment_1 \
    --checkpoint_dir checkpoints/assignment_1
# Out:
# ...
# Starting Assignment 1
# ...
#
# [2025-12-18 16:22:17] [assignment_1] [INFO] Logging to file: logs/assignment_1/assignment_1/assignment_1.log
# [2025-12-18 16:22:17] [assignment_1] [INFO] Initializing vocabulary
# [2025-12-18 16:22:17] [assignment_1] [INFO] Loading datasets
# Loaded 20000 samples
# Loaded 2000 samples
# Loaded 2000 samples
# [2025-12-18 16:22:17] [assignment_1] [INFO] Using device: cuda
# [2025-12-18 16:22:18] [assignment_1] [INFO] Starting training for 5 epochs
# ...
# Validating: 100%|██████████████████████| 63/63 [00:04<00:00, 12.89it/s, loss=6.1606, rouge_l=0.1568]
# [2025-12-18 16:23:55] [assignment_1] [INFO] [Epoch 1/5] Val Loss: 6.0628 | Val ROUGE-L: 0.1568
# [2025-12-18 16:23:56] [assignment_1] [INFO] New best model saved! ROUGE-L: 0.1568
# ...
# Validating: 100%|██████████████████████| 63/63 [00:04<00:00, 13.17it/s, loss=5.7618, rouge_l=0.2043]
# [2025-12-18 16:25:32] [assignment_1] [INFO] [Epoch 2/5] Val Loss: 5.7618 | Val ROUGE-L: 0.2043
# ...

# %% [markdown]
# ## BÀI 2: Seq2Seq with Additive Attention (Bahdanau)
#
# **Yêu cầu:**
# - Encoder-Decoder với 3 layers LSTM
# - Hidden size: 256
# - Attention: Bahdanau (Neural Machine Translation by Jointly Learning to Align and Translate)
# - Optimizer: Adam
# - Metric: ROUGE-L

# %%
# %%time
# Chạy Assignment 2: Additive Attention (Bahdanau)
# !python main.py \
    --assignment 2 \
    --train_path /kaggle/input/phomt-data/small-train.json \
    --val_path /kaggle/input/phomt-data/small-dev.json \
    --test_path /kaggle/input/phomt-data/small-test.json \
    --embedding_dim 256 \
    --hidden_dim 256 \
    --num_layers 3 \
    --dropout 0.3 \
    --batch_size 32 \
    --epochs 5 \
    --patience 5 \
    --lr 0.001 \
    --log_dir logs/assignment_2 \
    --checkpoint_dir checkpoints/assignment_2
# Out:
# ...
# Starting Assignment 2
# ...
#
# [2025-12-18 16:33:53] [assignment_2] [INFO] Logging to file: logs/assignment_2/assignment_2/assignment_2.log
# [2025-12-18 16:33:53] [assignment_2] [INFO] Initializing vocabulary
# [2025-12-18 16:33:53] [assignment_2] [INFO] Loading datasets
# Loaded 20000 samples
# Loaded 2000 samples
# Loaded 2000 samples
# [2025-12-18 16:33:54] [assignment_2] [INFO] Using device: cuda
# [2025-12-18 16:33:54] [assignment_2] [INFO] Starting training for 5 epochs
# ...
# Validating: 100%|██████████████████████| 63/63 [00:07<00:00,  8.37it/s, loss=5.8005, rouge_l=0.1830]
# [2025-12-18 16:36:14] [assignment_2] [INFO] [Epoch 1/5] Val Loss: 5.8005 | Val ROUGE-L: 0.1830
# [2025-12-18 16:36:14] [assignment_2] [INFO] New best model saved! ROUGE-L: 0.1830
# ...
# Validating: 100%|██████████████████████| 63/63 [00:07<00:00,  8.36it/s, loss=5.4857, rouge_l=0.2216]
# [2025-12-18 16:38:32] [assignment_2] [INFO] [Epoch 2/5] Val Loss: 5.4857 | Val ROUGE-L: 0.2216
# ...

# %% [markdown]
# ## BÀI 3: Seq2Seq with Global Attention (Luong)
#
# **Yêu cầu:**
# - Encoder-Decoder với 3 layers LSTM
# - Hidden size: 256
# - Attention: Luong (Effective Approaches to Attention-based Neural Machine Translation)
# - Optimizer: Adam
# - Metric: ROUGE-L

# %%
# %%time
# Chạy Assignment 3: Global Attention (Luong)
# !python main.py \
    --assignment 3 \
    --train_path /kaggle/input/phomt-data/small-train.json \
    --val_path /kaggle/input/phomt-data/small-dev.json \
    --test_path /kaggle/input/phomt-data/small-test.json \
    --embedding_dim 256 \
    --hidden_dim 256 \
    --num_layers 3 \
    --dropout 0.3 \
    --batch_size 32 \
    --epochs 3 \
    --patience 5 \
    --lr 0.001 \
    --log_dir logs/assignment_3 \
    --checkpoint_dir checkpoints/assignment_3
# Out:
# ...
# Starting Assignment 3
# ...
#
# [2025-12-18 16:45:42] [assignment_3] [INFO] Logging to file: logs/assignment_3/assignment_3/assignment_3.log
# [2025-12-18 16:45:43] [assignment_3] [INFO] Initializing vocabulary
# [2025-12-18 16:45:43] [assignment_3] [INFO] Loading datasets
# Loaded 20000 samples
# Loaded 2000 samples
# Loaded 2000 samples
# [2025-12-18 16:45:43] [assignment_3] [INFO] Using device: cuda
# [2025-12-18 16:45:44] [assignment_3] [INFO] Starting training for 3 epochs
# ...
# Validating: 100%|██████████████████████| 63/63 [00:06<00:00,  9.13it/s, loss=6.1213, rouge_l=0.1478]
# [2025-12-18 16:47:43] [assignment_3] [INFO] [Epoch 1/3] Val Loss: 6.1213 | Val ROUGE-L: 0.1478
# [2025-12-18 16:47:43] [assignment_3] [INFO] New best model saved! ROUGE-L: 0.1478
# ...
# Validating: 100%|██████████████████████| 63/63 [00:06<00:00,  9.11it/s, loss=5.7056, rouge_l=0.1932]
# [2025-12-18 16:49:42] [assignment_3] [INFO] [Epoch 2/3] Val Loss: 5.7056 | Val ROUGE-L: 0.1932
# ...
