# %%
# !git clone https://github.com/HKhangg/DS201_DeepLearning.1.git
# Out:
# Cloning into 'DS201_DeepLearning.1'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 30 (delta 9), reused 30 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (30/30), 11.54 MiB | 20.56 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
pip install torch torchvision scikit-learn tqdm numpy idx2numpy
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 106.1 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 79.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 86.7 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# !git pull
# Out:
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 10 (delta 4), reused 10 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (10/10), 2.16 KiB | 737.00 KiB/s, done.
# From https://github.com/HKhangg/DS201_DeepLearning.1
#    35296d7..bd4010e  main       -> origin/main
# Updating 35296d7..bd4010e
# Fast-forward
#  lab2/main.py              |  38 ++++++++++++-
#  lab2/pretrained_resnet.py |  19 +++++++
#  lab2/resnet18.py          | 138 ++++++++++++++++++++++++++++++++++++++++++++++
#  3 files changed, 194 insertions(+), 1 deletion(-)
#  create mode 100644 lab2/pretrained_resnet.py
#  create mode 100644 lab2/resnet18.py

# %%
# %cd /kaggle/working/DS201_DeepLearning.1
# Out:
# /kaggle/working/DS201_DeepLearning.1

# %%
# !python -m lab2.main --task 1
# Out:
# Epoch 1/10: 100%|██████████| 1875/1875 [00:05<00:00, 344.34batch/s, loss=1.4638]
# Epoch 1/10 finished | Average loss: 1.4638
# Epoch 2/10: 100%|██████████| 1875/1875 [00:04<00:00, 382.56batch/s, loss=0.3135]
# Epoch 2/10 finished | Average loss: 0.3135
# Epoch 3/10: 100%|██████████| 1875/1875 [00:04<00:00, 382.07batch/s, loss=0.2137]
# Epoch 3/10 finished | Average loss: 0.2137
# Epoch 4/10: 100%|██████████| 1875/1875 [00:04<00:00, 380.92batch/s, loss=0.1722]
# Epoch 4/10 finished | Average loss: 0.1722
# Epoch 5/10: 100%|██████████| 1875/1875 [00:04<00:00, 376.34batch/s, loss=0.1608]
# Epoch 5/10 finished | Average loss: 0.1608
# Epoch 6/10: 100%|██████████| 1875/1875 [00:05<00:00, 372.75batch/s, loss=0.1474]
# Epoch 6/10 finished | Average loss: 0.1474
# Epoch 7/10: 100%|██████████| 1875/1875 [00:05<00:00, 372.96batch/s, loss=0.1389]
# Epoch 7/10 finished | Average loss: 0.1389
# Epoch 8/10: 100%|██████████| 1875/1875 [00:04<00:00, 375.23batch/s, loss=0.1332]
# ...

# %%
# !python -m lab2.main --task 2
# Out:
# Epoch 1/10:  50%|██████▌      | 158/314 [01:49<01:46,  1.47batch/s, loss=3.2782]/usr/local/lib/python3.11/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/10: 100%|█████████████| 314/314 [03:32<00:00,  1.48batch/s, loss=3.0965]
# Epoch 1/10 finished | Average loss: 3.0965
# Epoch 2/10: 100%|█████████████| 314/314 [02:45<00:00,  1.89batch/s, loss=2.7847]
# Epoch 2/10 finished | Average loss: 2.7847
# Epoch 3/10: 100%|█████████████| 314/314 [02:47<00:00,  1.88batch/s, loss=2.6537]
# Epoch 3/10 finished | Average loss: 2.6537
# Epoch 4/10: 100%|█████████████| 314/314 [02:47<00:00,  1.88batch/s, loss=2.5207]
# Epoch 4/10 finished | Average loss: 2.5207
# Epoch 5/10: 100%|█████████████| 314/314 [02:45<00:00,  1.89batch/s, loss=2.4142]
# Epoch 5/10 finished | Average loss: 2.4142
# Epoch 6/10: 100%|█████████████| 314/314 [02:47<00:00,  1.88batch/s, loss=2.2789]
# ...

# %%
# !python -m lab2.main --task 3
# Out:
# 2025-11-06 16:26:23.846875: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762446384.006179     141 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762446384.055540     141 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Epoch 1/3:  74%|██████████▍   | 233/314 [01:56<00:38,  2.08batch/s, loss=3.0883]/usr/local/lib/python3.11/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# ...

# %%
# !python -m lab2.main --task 4
# Out:
# 2025-11-06 16:36:57.477287: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762447017.500646     159 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762447017.507721     159 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# config.json: 69.6kB [00:00, 75.4MB/s]
# model.safetensors: 100%|█████████████████████| 102M/102M [00:01<00:00, 79.1MB/s]
# ...
