# %%
# !git clone https://github.com/HKhangg/DS201_DeepLearning.1.git
# %cd DS201_DeepLearning.1/Lab3
# Out:
# Cloning into 'DS201_DeepLearning.1'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 89 (delta 29), reused 89 (delta 29), pack-reused 0 (from 0)
# Receiving objects: 100% (89/89), 11.56 MiB | 10.84 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# /kaggle/working/DS201_DeepLearning.1/Lab3/DS201_DeepLearning.1/Lab3/DS201_DeepLearning.1/Lab3/DS201_DeepLearning.1/Lab3/DS201_DeepLearning.1/Lab3

# %%
# !python -m utils.main --task 1
# Out:
# ...
# BÀI 1: LSTM cho phân loại văn bản
# ...
#
# 2025-12-04 16:41:40 - TaskLogger - INFO - Creating vocab
# 2025-12-04 16:41:42 - TaskLogger - INFO - Loading datasets & dataloaders
# ...
# Validating: 100%|████████████████████████████| 50/50 [00:00<00:00, 91.71it/s, loss=0.3314]
# 2025-12-04 16:41:53 - TaskLogger - INFO - [Epoch 1] Val_loss=0.3314 | Val_Macro-F1=0.6106
# 2025-12-04 16:41:53 - TaskLogger - INFO - New BEST model saved (F1=0.6106)
# ...
# Validating: 100%|████████████████████████████| 50/50 [00:00<00:00, 92.18it/s, loss=0.2970]
# 2025-12-04 16:42:00 - TaskLogger - INFO - [Epoch 2] Val_loss=0.2970 | Val_Macro-F1=0.6161
# 2025-12-04 16:42:00 - TaskLogger - INFO - New BEST model saved (F1=0.6161)
# ...
# Validating: 100%|████████████████████████████| 50/50 [00:00<00:00, 91.85it/s, loss=0.2853]
# 2025-12-04 16:42:08 - TaskLogger - INFO - [Epoch 3] Val_loss=0.2796 | Val_Macro-F1=0.7302
# 2025-12-04 16:42:08 - TaskLogger - INFO - New BEST model saved (F1=0.7302)
# ...

# %%
# !python -m utils.main --task 2
# Out:
# ...
# BÀI 2: GRU cho phân loại văn bản
# ...
#
# 2025-12-04 16:44:39 - TaskLogger - INFO - Creating vocab
# 2025-12-04 16:44:41 - TaskLogger - INFO - Loading datasets & dataloaders
# ...
# Validating: 100%|████████████████████████████| 50/50 [00:00<00:00, 99.16it/s, loss=0.3457]
# 2025-12-04 16:44:50 - TaskLogger - INFO - [Epoch 1] Val_loss=0.2973 | Val_Macro-F1=0.6995
# 2025-12-04 16:44:50 - TaskLogger - INFO - New BEST model saved (F1=0.6995)
# ...
# Validating: 100%|████████████████████████████| 50/50 [00:00<00:00, 92.47it/s, loss=0.3041]
# 2025-12-04 16:44:57 - TaskLogger - INFO - [Epoch 2] Val_loss=0.2554 | Val_Macro-F1=0.7753
# 2025-12-04 16:44:57 - TaskLogger - INFO - New BEST model saved (F1=0.7753)
# ...
# Validating: 100%|████████████████████████████| 50/50 [00:00<00:00, 98.77it/s, loss=0.3274]
# 2025-12-04 16:45:03 - TaskLogger - INFO - [Epoch 3] Val_loss=0.2750 | Val_Macro-F1=0.7700
# ...
# Validating: 100%|████████████████████████████| 50/50 [00:00<00:00, 99.75it/s, loss=0.3637]
# ...

# %%
# !python utils/main.py --task 3
# Out:
# ...
# BÀI 3: Bi-LSTM cho gán nhãn chuỗi
# ...
#
# Đang tải PhoNER dataset...
# ✓ Đã tải train_word.json
# ✓ Đã tải dev_word.json
# ✓ Đã tải test_word.json
# ✓ Hoàn thành tải dataset!
#
# 2025-12-04 16:54:03 - TaskLogger - INFO - Creating vocab
# 2025-12-04 16:54:03 - TaskLogger - INFO - Loading datasets & dataloaders
# ...
# Validating: 100%|███████████████████████████| 63/63 [00:00<00:00, 133.05it/s, loss=0.3309]
# 2025-12-04 16:54:08 - TaskLogger - INFO - [Epoch 1] Val_loss=0.2889 | Val_Macro-F1=0.5416
# 2025-12-04 16:54:08 - TaskLogger - INFO - New BEST model saved (F1=0.5416)
# ...
# Validating: 100%|███████████████████████████| 63/63 [00:00<00:00, 134.17it/s, loss=0.2053]
# 2025-12-04 16:54:12 - TaskLogger - INFO - [Epoch 2] Val_loss=0.1825 | Val_Macro-F1=0.6517
# 2025-12-04 16:54:12 - TaskLogger - INFO - New BEST model saved (F1=0.6517)
# ...
# Validating: 100%|███████████████████████████| 63/63 [00:00<00:00, 135.70it/s, loss=0.1739]
# ...
